# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajay176854/Ajay/blob/main/Linear_Regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
# Out:
# (30, 2)

# %%
x=df.drop('Salary',axis=1)

# %%
y=df.Salary

# %%
x.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
y.head()
# Out:
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.30)

# %%
print(x_train.shape)
# Out:
# (21, 1)

# %%
x_test.shape
# Out:
# (9, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([ 40817.78327049, 123188.08258899,  65154.46261459,  63282.41035735,
#        115699.87356004, 108211.66453108, 116635.89968866,  64218.43648597,
#         76386.77615802])

# %%
y_test
# Out:
# 2      37731
# 28    122391
# 13     57081
# 10     63218
# 26    116969
# 24    109431
# 27    112635
# 11     55794
# 17     83088
# Name: Salary, dtype: int64

# %%
accuracy=y_pred-y_test

# %%
accuracy
# Out:
# 2     3086.783270
# 28     797.082589
# 13    8073.462615
# 10      64.410357
# 26   -1269.126440
# 24   -1219.335469
# 27    4000.899689
# 11    8424.436486
# 17   -6701.223842
# Name: Salary, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)

# %%
print(f"R² Score: {r2:.4f}")
# Out:
# R² Score: 0.9741

# %%
import pickle

# %%
file_name="Salary.sav"

# %%
pickle.dump(LR,open(file_name,'wb'))

# %%
load_model=pickle.load(open(file_name,'rb'))

# %%
result=load_model.predict([[1.1]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(result)
# Out:
# [37073.67875601]
